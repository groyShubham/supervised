# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %%
pd.read_csv("magic04.data")
# Out:
#         28.7967   16.0021  2.6449  0.3918  0.1982   27.7004    22.011  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        -8.2027   40.092   81.8828  g
# 0      -9.9574   6.3609  205.2610  g
# 1     -45.2160  76.9600  256.7880  g
# 2      -7.1513  10.4490  116.7370  g
# 3      21.8393   4.6480  356.4620  g
# 4       9.8145   3.6130  238.0980  g
# ...        ...      ...       ... ..
# 19014   2.8766   2.4229  106.8258  h
# 19015  -2.9632  86.7975  247.4560  h
# 19016  -9.4662  30.2987  256.5166  h
# 19017 -63.8389  84.6874  408.3166  h
# 19018  31.4755  52.7310  272.3174  h
#
# [19019 rows x 11 columns]

# %%
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]

# %%
df = pd.read_csv("magic04.data",names=cols)

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df['class'].unique()
# Out:
# array(['g', 'h'], dtype=object)

# %%
#Changing the value of g to 1 and h to 0:
df['class'] = (df['class'] == 'g').astype(int)

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
for label in cols[:-1]:
    print(label)
# Out:
# fLength
# fWidth
# fSize
# fConc
# fConc1
# fAsym
# fM3Long
# fM3Trans
# fAlpha
# fDist

# %%
for label in cols[:-1]:
    plt.hist(df[df["class"] == 1][label], color = 'red', label='Gamma', alpha=0.7 , density = True)
    plt.hist(df[df["class"] == 0][label], color = 'blue', label='Hadron', alpha=0.7 , density = True)
    plt.title(label)
    plt.ylabel("Probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/lib/_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges

# %% [markdown]
# Test, Valid and Train Datasets

# %%
train, valid, test = np.split(df.sample(frac=1), [(int(0.6*len(df))), (int(0.8*len(df)))])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:54: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
def scaleDataset(dataframe, oversample=False):
    x = dataframe[dataframe.columns[:-1 ]].values
    y = dataframe[dataframe.columns[-1]].values

    scalar = StandardScaler()
    x = scalar.fit_transform(x)

    if oversample:
        ros = RandomOverSampler()
        x,y = ros.fit_resample(x,y)

    data= np.hstack((x,np.reshape(y,(-1,1))))

    return data, x,y

# %%
train, x_train, y_train = scaleDataset(train, oversample=True)
valid, x_valid, y_valid = scaleDataset(valid)
test, x_test, y_test = scaleDataset(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 train, x_train, y_train = scaleDataset(train, oversample=True)
#       2 valid, x_valid, y_valid = scaleDataset(valid)
#       3 test, x_test, y_test = scaleDataset(test)
#
# Cell In[47], line 10, in scaleDataset(dataframe, oversample)
#       8 if oversample:
#       9     ros = RandomOverSampler()
# ---> 10     x,y = ros.fit_resample(x,y)
#      12 data= np.hstack((x,np.reshape(y,(-1,1))))
#      14 return data, x,y
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/imblearn/base.py:204, in BaseSampler.fit_resample(self, X, y, **params)
#     183 def fit_resample(self, X, y, **params):
#     184     """Resample the dataset.
#     185
#     186     Parameters
#    (...)    202         The corresponding label of `X_resampled`.
#     203     """
# --> 204     return super().fit_resample(X, y, **params)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/imblearn/base.py:103, in SamplerMixin.fit_resample(self, X, y, **params)
#     100 arrays_transformer = ArraysTransformer(X, y)
#     101 X, y, binarize_y = self._check_X_y(X, y)
# --> 103 self.sampling_strategy_ = check_sampling_strategy(
#     104     self.sampling_strategy, y, self._sampling_type
#     105 )
#     107 output = self._fit_resample(X, y, **params)
#     109 y_ = (
#     110     label_binarize(output[1], classes=np.unique(y)) if binarize_y else output[1]
#     111 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/imblearn/utils/_validation.py:533, in check_sampling_strategy(sampling_strategy, y, sampling_type, **kwargs)
#     527     raise ValueError(
#     528         f"'sampling_type' should be one of {SAMPLING_KIND}. "
#     529         f"Got '{sampling_type} instead."
#     530     )
#     532 if np.unique(y).size <= 1:
# --> 533     raise ValueError(
#     534         "The target 'y' needs to have more than 1 class. "
#     535         f"Got {np.unique(y).size} class instead"
#     536     )
#     538 if sampling_type in ("ensemble", "bypass"):
#     539     return sampling_strategy
#
# ValueError: The target 'y' needs to have more than 1 class. Got 1 class instead

# %%
len(y_train)
# Out:
# 14794

# %%
len(x_train)
# Out:
# 14794

# %% [markdown]
# KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
knn_model = KNeighborsClassifier(n_neighbors=2)

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred = knn_model.predict(x_test)

# %%
#When kNN is considered 1
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.74      1339
#            1       0.87      0.81      0.84      2465
#
#     accuracy                           0.80      3804
#    macro avg       0.78      0.80      0.79      3804
# weighted avg       0.81      0.80      0.80      3804

# %%
#When KNN is considered 4
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.74      1339
#            1       0.87      0.81      0.84      2465
#
#     accuracy                           0.80      3804
#    macro avg       0.78      0.80      0.79      3804
# weighted avg       0.81      0.80      0.80      3804

# %%
#When kNN is considered 2
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.74      1339
#            1       0.87      0.81      0.84      2465
#
#     accuracy                           0.80      3804
#    macro avg       0.78      0.80      0.79      3804
# weighted avg       0.81      0.80      0.80      3804

# %% [markdown]
# Naive-Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model = nb_model.fit(x_train, y_train)

# %%
y_pred = nb_model.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.41      0.51      1339
#            1       0.73      0.89      0.81      2465
#
#     accuracy                           0.72      3804
#    macro avg       0.70      0.65      0.66      3804
# weighted avg       0.71      0.72      0.70      3804

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()
log_model = log_model.fit(x_train,y_train)

# %%
y_pred = log_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70      1339
#            1       0.84      0.82      0.83      2465
#
#     accuracy                           0.78      3804
#    macro avg       0.76      0.77      0.76      3804
# weighted avg       0.79      0.78      0.78      3804

# %% [markdown]
# Support Vector Machines (SVM)

# %%
from sklearn.svm import SVC

# %%
sv_model = SVC()
